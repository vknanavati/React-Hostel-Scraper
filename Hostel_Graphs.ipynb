# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
df = pd.read_csv("Hostel_City_Ratings.csv", index_col=[0])
df.head()
df_copy = df.copy()

df_copy
# Out:
#    HI-Quebec- Auberge Internationale de Québec  QBEDS Hostel  \
# 0                                          9.5           9.1
# 1                                          9.8           9.5
# 2                                          9.5           8.8
# 3                                          9.0           8.3
# 4                                          9.1           9.4
# 5                                          8.9           9.1
# 6                                          9.0           9.1
#
#    Auberge de la Paix Quebec  Auberge Jeunesse LouLou's Backpacker Hostel  \
# 0                        8.8                                          9.9
# 1                        9.8                                          8.8
# 2                        8.9                                          9.9
# 3                        7.8                                          9.4
# 4                        8.5                                          9.8
# 5                        8.4                                          9.8
# 6                        8.2                                          9.7
#
#    La Belle Planete Backpacker Hostel Downtown Quebec  Quebec Central Downtown
# 0                                                6.0                         8
# 1                                                7.5                         4
# 2                                                6.5                         6
# 3                                                5.5                         8
# 4                                                6.5                         6
# 5                                                6.5                         8
# 6                                                5.5                         8

# %%
new_df = df_copy.T.reset_index()
new_df
