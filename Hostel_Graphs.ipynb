# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
df = pd.read_csv("Hostel_City_Ratings.csv", index_col=[0])
df.head()
df_copy = df.copy()

df_copy
# Out:
#    Wombat's City Hostel London  Palmers Lodge - Swiss Cottage  \
# 0                          9.7                            9.1
# 1                          9.0                            8.5
# 2                          9.5                            9.0
# 3                          9.3                            8.3
# 4                          9.4                            8.5
# 5                          9.2                            8.7
# 6                          9.3                            8.3
#
#    Urbany Hostel London  Onefam Waterloo  Onefam Notting Hill  \
# 0                   9.8              9.7                  9.9
# 1                   9.6              9.3                  9.7
# 2                   9.8              9.8                  9.9
# 3                   9.6              9.7                  9.7
# 4                   9.5              9.1                  9.5
# 5                   9.4              9.4                  9.6
# 6                   9.3              8.9                  9.4
#
#    NX London Hostel  Clink261  Astor Museum Inn  \
# 0               9.1       8.9               9.2
# 1               8.9       9.2               9.8
# 2               9.0       8.9               9.5
# 3               8.7       7.2               8.4
# 4               8.8       7.7               8.4
# 5               9.1       7.8               8.6
# 6               8.8       7.5               8.0
#
#    Hostelle - women only hostel London  Destinations Hostels @ The Gallery  \
# 0                                  9.1                                 9.5
# 1                                  8.1                                 9.4
# 2                                  9.2                                 9.4
# 3                                  8.5                                 8.7
# 4                                  7.9                                 9.1
# 5                                  8.5                                 9.0
# 6                                  8.1                                 8.7
#
#    ...  St Christopher's Greenwich  St Christopher's Inn - Liverpool Street  \
# 0  ...                         8.0                                      9.1
# 1  ...                         8.7                                      8.6
# 2  ...                         8.4                                      8.3
# 3  ...                         7.3                                      7.7
# 4  ...                         6.9                                      8.5
# 5  ...                         7.5                                      8.2
# 6  ...                         7.1                                      7.7
#
#    PubLove @ The Rose & Crown  YHA London Thameside  Prime Backpackers Angel  \
# 0                         8.8                   9.6                      9.1
# 1                         9.2                   8.4                      9.5
# 2                         8.8                   9.7                      9.3
# 3                         8.0                   8.5                      8.8
# 4                         7.2                   9.1                      8.1
# 5                         7.8                   9.3                      8.7
# 6                         7.5                   8.5                      8.2
#
#    Park Villa  YHA London Earls Court  St Christopher's Oasis-Female Only  \
# 0        10.0                     9.2                                 9.3
# 1         9.1                     9.2                                 9.5
# 2         9.5                     9.6                                 8.3
# 3         8.0                     8.5                                 8.5
# 4         9.5                     9.2                                 7.5
# 5         8.9                     9.2                                 8.3
# 6         9.1                     8.4                                 8.3
#
#    YHA London St Pauls  The Backpackshack
# 0                  8.8                8.9
# 1                  9.2                8.9
# 2                  8.5                9.4
# 3                  6.6                7.4
# 4                  7.9                7.6
# 5                  8.2                8.7
# 6                  7.4                7.2
#
# [7 rows x 30 columns]

# %%
df_test = df_copy.set_axis(['Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value', 'Facilities'], axis=0, copy=True)

# %%
df_test.loc['Average']= df.mean()
df_test
# Out:
#              Wombat's City Hostel London  Palmers Lodge - Swiss Cottage  \
# Security                        9.700000                       9.100000
# Location                        9.000000                       8.500000
# Staff                           9.500000                       9.000000
# Atmosphere                      9.300000                       8.300000
# Cleanliness                     9.400000                       8.500000
# Value                           9.200000                       8.700000
# Facilities                      9.300000                       8.300000
# Average                         9.342857                       8.628571
#
#              Urbany Hostel London  Onefam Waterloo  Onefam Notting Hill  \
# Security                 9.800000         9.700000             9.900000
# Location                 9.600000         9.300000             9.700000
# Staff                    9.800000         9.800000             9.900000
# Atmosphere               9.600000         9.700000             9.700000
# Cleanliness              9.500000         9.100000             9.500000
# Value                    9.400000         9.400000             9.600000
# Facilities               9.300000         8.900000             9.400000
# Average                  9.571429         9.414286             9.671429
#
#              NX London Hostel  Clink261  Astor Museum Inn  \
# Security             9.100000  8.900000          9.200000
# Location             8.900000  9.200000          9.800000
# Staff                9.000000  8.900000          9.500000
# Atmosphere           8.700000  7.200000          8.400000
# Cleanliness          8.800000  7.700000          8.400000
# Value                9.100000  7.800000          8.600000
# Facilities           8.800000  7.500000          8.000000
# Average              8.914286  8.171429          8.842857
#
#              Hostelle - women only hostel London  \
# Security                                9.100000
# Location                                8.100000
# Staff                                   9.200000
# Atmosphere                              8.500000
# Cleanliness                             7.900000
# Value                                   8.500000
# Facilities                              8.100000
# Average                                 8.485714
#
#              Destinations Hostels @ The Gallery  ...  \
# Security                               9.500000  ...
# Location                               9.400000  ...
# Staff                                  9.400000  ...
# Atmosphere                             8.700000  ...
# Cleanliness                            9.100000  ...
# Value                                  9.000000  ...
# Facilities                             8.700000  ...
# Average                                9.114286  ...
#
#              St Christopher's Greenwich  \
# Security                            8.0
# Location                            8.7
# Staff                               8.4
# Atmosphere                          7.3
# Cleanliness                         6.9
# Value                               7.5
# Facilities                          7.1
# Average                             7.7
#
#              St Christopher's Inn - Liverpool Street  \
# Security                                         9.1
# Location                                         8.6
# Staff                                            8.3
# Atmosphere                                       7.7
# Cleanliness                                      8.5
# Value                                            8.2
# Facilities                                       7.7
# Average                                          8.3
#
#              PubLove @ The Rose & Crown  YHA London Thameside  \
# Security                       8.800000              9.600000
# Location                       9.200000              8.400000
# Staff                          8.800000              9.700000
# Atmosphere                     8.000000              8.500000
# Cleanliness                    7.200000              9.100000
# Value                          7.800000              9.300000
# Facilities                     7.500000              8.500000
# Average                        8.185714              9.014286
#
#              Prime Backpackers Angel  Park Villa  YHA London Earls Court  \
# Security                    9.100000   10.000000                9.200000
# Location                    9.500000    9.100000                9.200000
# Staff                       9.300000    9.500000                9.600000
# Atmosphere                  8.800000    8.000000                8.500000
# Cleanliness                 8.100000    9.500000                9.200000
# Value                       8.700000    8.900000                9.200000
# Facilities                  8.200000    9.100000                8.400000
# Average                     8.814286    9.157143                9.042857
#
#              St Christopher's Oasis-Female Only  YHA London St Pauls  \
# Security                               9.300000             8.800000
# Location                               9.500000             9.200000
# Staff                                  8.300000             8.500000
# Atmosphere                             8.500000             6.600000
# Cleanliness                            7.500000             7.900000
# Value                                  8.300000             8.200000
# Facilities                             8.300000             7.400000
# Average                                8.528571             8.085714
#
#              The Backpackshack
# Security                   8.9
# Location                   8.9
# Staff                      9.4
# Atmosphere                 7.4
# Cleanliness                7.6
# Value                      8.7
# Facilities                 7.2
# Average                    8.3
#
# [8 rows x 30 columns]

# %%
df_test = df_test.T.reset_index()
df_test = df_test.set_axis(['Name', 'Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value', 'Facilities', 'Average'], axis=1, copy=True)
df_test
# Out:
#                                        Name  Security  Location  Staff  \
# 0               Wombat's City Hostel London       9.7       9.0    9.5
# 1             Palmers Lodge - Swiss Cottage       9.1       8.5    9.0
# 2                      Urbany Hostel London       9.8       9.6    9.8
# 3                           Onefam Waterloo       9.7       9.3    9.8
# 4                       Onefam Notting Hill       9.9       9.7    9.9
# 5                          NX London Hostel       9.1       8.9    9.0
# 6                                  Clink261       8.9       9.2    8.9
# 7                          Astor Museum Inn       9.2       9.8    9.5
# 8       Hostelle - women only hostel London       9.1       8.1    9.2
# 9        Destinations Hostels @ The Gallery       9.5       9.4    9.4
# 10                  Smart Camden Inn Hostel       9.3       9.1    8.9
# 11                       London Backpackers       8.9       7.7    9.2
# 12                  Saint James Backpackers       7.7       9.1    8.7
# 13                        The Walrus Hostel       8.5       8.9    8.5
# 14                 YHA London Oxford Street       9.8       9.9    9.5
# 15              Smart Hyde Park View Hostel       8.8       9.2    8.4
# 16                 Barmy Badger Backpackers       9.6       9.6    9.6
# 17               Kabannas London St Pancras       8.9       9.3    9.1
# 18                       YHA London Central       8.8       9.3    9.0
# 19            International Students  House       9.7       9.9    9.3
# 20               St Christopher's Greenwich       8.0       8.7    8.4
# 21  St Christopher's Inn - Liverpool Street       9.1       8.6    8.3
# 22               PubLove @ The Rose & Crown       8.8       9.2    8.8
# 23                     YHA London Thameside       9.6       8.4    9.7
# 24                  Prime Backpackers Angel       9.1       9.5    9.3
# 25                               Park Villa      10.0       9.1    9.5
# 26                   YHA London Earls Court       9.2       9.2    9.6
# 27       St Christopher's Oasis-Female Only       9.3       9.5    8.3
# 28                      YHA London St Pauls       8.8       9.2    8.5
# 29                        The Backpackshack       8.9       8.9    9.4
#
#     Atmosphere  Cleanliness  Value  Facilities   Average
# 0          9.3          9.4    9.2         9.3  9.342857
# 1          8.3          8.5    8.7         8.3  8.628571
# 2          9.6          9.5    9.4         9.3  9.571429
# 3          9.7          9.1    9.4         8.9  9.414286
# 4          9.7          9.5    9.6         9.4  9.671429
# 5          8.7          8.8    9.1         8.8  8.914286
# 6          7.2          7.7    7.8         7.5  8.171429
# 7          8.4          8.4    8.6         8.0  8.842857
# 8          8.5          7.9    8.5         8.1  8.485714
# 9          8.7          9.1    9.0         8.7  9.114286
# 10         7.9          8.9    8.4         8.4  8.700000
# 11         7.9          8.2    8.6         8.5  8.428571
# 12         8.2          7.1    7.9         7.6  8.042857
# 13         7.7          7.9    8.1         7.6  8.171429
# 14         8.1          8.6    8.9         8.5  9.042857
# 15         7.4          8.1    8.1         7.5  8.214286
# 16         8.8          9.0    9.2         9.1  9.271429
# 17         7.5          8.1    7.9         7.6  8.342857
# 18         7.8          8.4    8.4         7.9  8.514286
# 19         8.6          9.0    8.7         8.4  9.085714
# 20         7.3          6.9    7.5         7.1  7.700000
# 21         7.7          8.5    8.2         7.7  8.300000
# 22         8.0          7.2    7.8         7.5  8.185714
# 23         8.5          9.1    9.3         8.5  9.014286
# 24         8.8          8.1    8.7         8.2  8.814286
# 25         8.0          9.5    8.9         9.1  9.157143
# 26         8.5          9.2    9.2         8.4  9.042857
# 27         8.5          7.5    8.3         8.3  8.528571
# 28         6.6          7.9    8.2         7.4  8.085714
# 29         7.4          7.6    8.7         7.2  8.300000

# %%
avg_graph = df_test.iloc[:, [0,8]].head(46)
avg_graph = avg_graph.sort_values('Average', ascending=False)
avg_graph
# Out:
#                                        Name   Average
# 4                       Onefam Notting Hill  9.671429
# 2                      Urbany Hostel London  9.571429
# 3                           Onefam Waterloo  9.414286
# 0               Wombat's City Hostel London  9.342857
# 16                 Barmy Badger Backpackers  9.271429
# 25                               Park Villa  9.157143
# 9        Destinations Hostels @ The Gallery  9.114286
# 19            International Students  House  9.085714
# 14                 YHA London Oxford Street  9.042857
# 26                   YHA London Earls Court  9.042857
# 23                     YHA London Thameside  9.014286
# 5                          NX London Hostel  8.914286
# 7                          Astor Museum Inn  8.842857
# 24                  Prime Backpackers Angel  8.814286
# 10                  Smart Camden Inn Hostel  8.700000
# 1             Palmers Lodge - Swiss Cottage  8.628571
# 27       St Christopher's Oasis-Female Only  8.528571
# 18                       YHA London Central  8.514286
# 8       Hostelle - women only hostel London  8.485714
# 11                       London Backpackers  8.428571
# 17               Kabannas London St Pancras  8.342857
# 29                        The Backpackshack  8.300000
# 21  St Christopher's Inn - Liverpool Street  8.300000
# 15              Smart Hyde Park View Hostel  8.214286
# 22               PubLove @ The Rose & Crown  8.185714
# 13                        The Walrus Hostel  8.171429
# 6                                  Clink261  8.171429
# 28                      YHA London St Pauls  8.085714
# 12                  Saint James Backpackers  8.042857
# 20               St Christopher's Greenwich  7.700000

# %%
top_ten = avg_graph.sort_values(by= 'Average', ascending=False)[:10]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_ten.Name, x=top_ten.Average)
plt.xticks()
plt.xlabel('Average Rating')
plt.ylabel('Hostel Name')
plt.title('Top Hostels')
plt.show()

# %%
highest_security = df_test.iloc[:, [0,1]].head(46)
highest_security = highest_security.sort_values('Security', ascending=False)
print(highest_security)
# Out:
#                                        Name  Security
# 25                               Park Villa      10.0
# 4                       Onefam Notting Hill       9.9
# 2                      Urbany Hostel London       9.8
# 14                 YHA London Oxford Street       9.8
# 0               Wombat's City Hostel London       9.7
# 19            International Students  House       9.7
# 3                           Onefam Waterloo       9.7
# 23                     YHA London Thameside       9.6
# 16                 Barmy Badger Backpackers       9.6
# 9        Destinations Hostels @ The Gallery       9.5
# 10                  Smart Camden Inn Hostel       9.3
# 27       St Christopher's Oasis-Female Only       9.3
# 26                   YHA London Earls Court       9.2
# 7                          Astor Museum Inn       9.2
# 8       Hostelle - women only hostel London       9.1
# 24                  Prime Backpackers Angel       9.1
# 1             Palmers Lodge - Swiss Cottage       9.1
# 5                          NX London Hostel       9.1
# 21  St Christopher's Inn - Liverpool Street       9.1
# 29                        The Backpackshack       8.9
# 17               Kabannas London St Pancras       8.9
# 11                       London Backpackers       8.9
# 6                                  Clink261       8.9
# 18                       YHA London Central       8.8
# 22               PubLove @ The Rose & Crown       8.8
# 28                      YHA London St Pauls       8.8
# 15              Smart Hyde Park View Hostel       8.8
# 13                        The Walrus Hostel       8.5
# 20               St Christopher's Greenwich       8.0
# 12                  Saint James Backpackers       7.7

# %%
top_security = highest_security.sort_values(by= 'Security', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_security.Name, x=top_security.Security)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Security')
plt.show()

# %%
highest_location = df_test.iloc[:, [0,2]].head(10)
highest_location = highest_location.sort_values('Location', ascending=False)
print(highest_location)
# Out:
#                                   Name  Location
# 7                     Astor Museum Inn       9.8
# 4                  Onefam Notting Hill       9.7
# 2                 Urbany Hostel London       9.6
# 9   Destinations Hostels @ The Gallery       9.4
# 3                      Onefam Waterloo       9.3
# 6                             Clink261       9.2
# 0          Wombat's City Hostel London       9.0
# 5                     NX London Hostel       8.9
# 1        Palmers Lodge - Swiss Cottage       8.5
# 8  Hostelle - women only hostel London       8.1

# %%
top_location = highest_location.sort_values(by= 'Location', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_location.Name, x=top_location.Location)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Location')
plt.show()

# %%
highest_staff = df_test.iloc[:, [0,3]].head(10)
highest_staff = highest_staff.sort_values('Staff', ascending=False)
print(highest_staff)
# Out:
#                                   Name  Staff
# 4                  Onefam Notting Hill    9.9
# 2                 Urbany Hostel London    9.8
# 3                      Onefam Waterloo    9.8
# 0          Wombat's City Hostel London    9.5
# 7                     Astor Museum Inn    9.5
# 9   Destinations Hostels @ The Gallery    9.4
# 8  Hostelle - women only hostel London    9.2
# 1        Palmers Lodge - Swiss Cottage    9.0
# 5                     NX London Hostel    9.0
# 6                             Clink261    8.9

# %%
top_staff = highest_staff.sort_values(by= 'Staff', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_staff.Name, x=top_staff.Staff)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Staff')
plt.show()

# %%
highest_atmosphere = df_test.iloc[:, [0,4]].head(10)
highest_atmosphere = highest_atmosphere.sort_values('Atmosphere', ascending=False)
print(highest_atmosphere)
# Out:
#                                   Name  Atmosphere
# 3                      Onefam Waterloo         9.7
# 4                  Onefam Notting Hill         9.7
# 2                 Urbany Hostel London         9.6
# 0          Wombat's City Hostel London         9.3
# 5                     NX London Hostel         8.7
# 9   Destinations Hostels @ The Gallery         8.7
# 8  Hostelle - women only hostel London         8.5
# 7                     Astor Museum Inn         8.4
# 1        Palmers Lodge - Swiss Cottage         8.3
# 6                             Clink261         7.2

# %%
top_atmosphere = highest_atmosphere.sort_values(by= 'Atmosphere', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_atmosphere.Name, x=top_atmosphere.Atmosphere)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Atmosphere')
plt.show()

# %%
highest_clean = df_test.iloc[:, [0,5]].head(10)
highest_clean = highest_clean.sort_values('Cleanliness', ascending=False)
print(highest_clean)
# Out:
#                                   Name  Cleanliness
# 2                 Urbany Hostel London          9.5
# 4                  Onefam Notting Hill          9.5
# 0          Wombat's City Hostel London          9.4
# 3                      Onefam Waterloo          9.1
# 9   Destinations Hostels @ The Gallery          9.1
# 5                     NX London Hostel          8.8
# 1        Palmers Lodge - Swiss Cottage          8.5
# 7                     Astor Museum Inn          8.4
# 8  Hostelle - women only hostel London          7.9
# 6                             Clink261          7.7

# %%
top_clean = highest_clean.sort_values(by= 'Cleanliness', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_clean.Name, x=top_clean.Cleanliness)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Cleanliness')
plt.show()

# %%
highest_value = df_test.iloc[:, [0,6]].head(10)
highest_value = highest_value.sort_values('Value', ascending=False)
print(highest_value)
# Out:
#                                   Name  Value
# 4                  Onefam Notting Hill    9.6
# 2                 Urbany Hostel London    9.4
# 3                      Onefam Waterloo    9.4
# 0          Wombat's City Hostel London    9.2
# 5                     NX London Hostel    9.1
# 9   Destinations Hostels @ The Gallery    9.0
# 1        Palmers Lodge - Swiss Cottage    8.7
# 7                     Astor Museum Inn    8.6
# 8  Hostelle - women only hostel London    8.5
# 6                             Clink261    7.8

# %%
top_value = highest_value.sort_values(by= 'Value', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_value.Name, x=top_value.Value)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Value')
plt.show()

# %%
highest_facility = df_test.iloc[:, [0,7]].head(10)
highest_facility = highest_facility.sort_values('Facilities', ascending=False)
print(highest_facility)
# Out:
#                                   Name  Facilities
# 4                  Onefam Notting Hill         9.4
# 0          Wombat's City Hostel London         9.3
# 2                 Urbany Hostel London         9.3
# 3                      Onefam Waterloo         8.9
# 5                     NX London Hostel         8.8
# 9   Destinations Hostels @ The Gallery         8.7
# 1        Palmers Lodge - Swiss Cottage         8.3
# 8  Hostelle - women only hostel London         8.1
# 7                     Astor Museum Inn         8.0
# 6                             Clink261         7.5

# %%
top_facility = highest_facility.sort_values(by= 'Facilities', ascending=False)[:20]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_facility.Name, x=top_facility.Facilities)
plt.xticks()
plt.xlabel('Rating')
plt.ylabel('Hostel Name')
plt.title('Best Facilities')
plt.show()
