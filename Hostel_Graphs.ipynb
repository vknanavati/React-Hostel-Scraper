# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
df = pd.read_csv("Hostel_City_Ratings.csv", index_col=[0])
df.head()
df_copy = df.copy()

df_copy
# Out:
#    HI-Quebec- Auberge Internationale de Québec  QBEDS Hostel  \
# 0                                          9.5           9.1
# 1                                          9.8           9.5
# 2                                          9.5           8.8
# 3                                          9.0           8.3
# 4                                          9.1           9.4
# 5                                          8.9           9.1
# 6                                          9.0           9.1
#
#    Auberge de la Paix Quebec  Auberge Jeunesse LouLou's Backpacker Hostel  \
# 0                        8.8                                          9.9
# 1                        9.8                                          8.8
# 2                        8.9                                          9.9
# 3                        7.8                                          9.4
# 4                        8.5                                          9.8
# 5                        8.4                                          9.8
# 6                        8.2                                          9.7
#
#    La Belle Planete Backpacker Hostel Downtown Quebec  Quebec Central Downtown
# 0                                                6.0                         8
# 1                                                7.5                         4
# 2                                                6.5                         6
# 3                                                5.5                         8
# 4                                                6.5                         6
# 5                                                6.5                         8
# 6                                                5.5                         8

# %%
df_test = df_copy.set_axis(['Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value for Money', 'Facilities'], axis=0, copy=True)
df_test
# Out:
#                  HI-Quebec- Auberge Internationale de Québec  QBEDS Hostel  \
# Security                                                 9.5           9.1
# Location                                                 9.8           9.5
# Staff                                                    9.5           8.8
# Atmosphere                                               9.0           8.3
# Cleanliness                                              9.1           9.4
# Value for Money                                          8.9           9.1
# Facilities                                               9.0           9.1
#
#                  Auberge de la Paix Quebec  \
# Security                               8.8
# Location                               9.8
# Staff                                  8.9
# Atmosphere                             7.8
# Cleanliness                            8.5
# Value for Money                        8.4
# Facilities                             8.2
#
#                  Auberge Jeunesse LouLou's Backpacker Hostel  \
# Security                                                 9.9
# Location                                                 8.8
# Staff                                                    9.9
# Atmosphere                                               9.4
# Cleanliness                                              9.8
# Value for Money                                          9.8
# Facilities                                               9.7
#
#                  La Belle Planete Backpacker Hostel Downtown Quebec  \
# Security                                                       6.0
# Location                                                       7.5
# Staff                                                          6.5
# Atmosphere                                                     5.5
# Cleanliness                                                    6.5
# Value for Money                                                6.5
# Facilities                                                     5.5
#
#                  Quebec Central Downtown
# Security                               8
# Location                               4
# Staff                                  6
# Atmosphere                             8
# Cleanliness                            6
# Value for Money                        8
# Facilities                             8

# %%
new_df = df_copy.T.reset_index()
new_df
# Out:
#                                                index    0    1    2    3    4  \
# 0        HI-Quebec- Auberge Internationale de Québec  9.5  9.8  9.5  9.0  9.1
# 1                                       QBEDS Hostel  9.1  9.5  8.8  8.3  9.4
# 2                          Auberge de la Paix Quebec  8.8  9.8  8.9  7.8  8.5
# 3        Auberge Jeunesse LouLou's Backpacker Hostel  9.9  8.8  9.9  9.4  9.8
# 4  La Belle Planete Backpacker Hostel Downtown Qu...  6.0  7.5  6.5  5.5  6.5
# 5                            Quebec Central Downtown  8.0  4.0  6.0  8.0  6.0
#
#      5    6
# 0  8.9  9.0
# 1  9.1  9.1
# 2  8.4  8.2
# 3  9.8  9.7
# 4  6.5  5.5
# 5  8.0  8.0

# %%
df_test.loc['avg']= df.mean()
df_test
# Out:
#                  HI-Quebec- Auberge Internationale de Québec  QBEDS Hostel  \
# Security                                            9.500000      9.100000
# Location                                            9.800000      9.500000
# Staff                                               9.500000      8.800000
# Atmosphere                                          9.000000      8.300000
# Cleanliness                                         9.100000      9.400000
# Value for Money                                     8.900000      9.100000
# Facilities                                          9.000000      9.100000
# avg                                                 9.257143      9.042857
#
#                  Auberge de la Paix Quebec  \
# Security                          8.800000
# Location                          9.800000
# Staff                             8.900000
# Atmosphere                        7.800000
# Cleanliness                       8.500000
# Value for Money                   8.400000
# Facilities                        8.200000
# avg                               8.628571
#
#                  Auberge Jeunesse LouLou's Backpacker Hostel  \
# Security                                            9.900000
# Location                                            8.800000
# Staff                                               9.900000
# Atmosphere                                          9.400000
# Cleanliness                                         9.800000
# Value for Money                                     9.800000
# Facilities                                          9.700000
# avg                                                 9.614286
#
#                  La Belle Planete Backpacker Hostel Downtown Quebec  \
# Security                                                  6.000000
# Location                                                  7.500000
# Staff                                                     6.500000
# Atmosphere                                                5.500000
# Cleanliness                                               6.500000
# Value for Money                                           6.500000
# Facilities                                                5.500000
# avg                                                       6.285714
#
#                  Quebec Central Downtown
# Security                        8.000000
# Location                        4.000000
# Staff                           6.000000
# Atmosphere                      8.000000
# Cleanliness                     6.000000
# Value for Money                 8.000000
# Facilities                      8.000000
# avg                             6.857143

# %%
df_test = df_test.T.reset_index()
df_test = df_test.set_axis(['Name', 'Security', 'Location', 'Staff', 'Atmosphere', 'Cleanliness', 'Value for Money', 'Facilities', 'Average'], axis=1, copy=True)
df_test
# Out:
#                                                 Name  Security  Location  \
# 0        HI-Quebec- Auberge Internationale de Québec       9.5       9.8
# 1                                       QBEDS Hostel       9.1       9.5
# 2                          Auberge de la Paix Quebec       8.8       9.8
# 3        Auberge Jeunesse LouLou's Backpacker Hostel       9.9       8.8
# 4  La Belle Planete Backpacker Hostel Downtown Qu...       6.0       7.5
# 5                            Quebec Central Downtown       8.0       4.0
#
#    Staff  Atmosphere  Cleanliness  Value for Money  Facilities   Average
# 0    9.5         9.0          9.1              8.9         9.0  9.257143
# 1    8.8         8.3          9.4              9.1         9.1  9.042857
# 2    8.9         7.8          8.5              8.4         8.2  8.628571
# 3    9.9         9.4          9.8              9.8         9.7  9.614286
# 4    6.5         5.5          6.5              6.5         5.5  6.285714
# 5    6.0         8.0          6.0              8.0         8.0  6.857143

# %%
avg_graph = df_test.iloc[:, [0,8]].head(46)
avg_graph = avg_graph.sort_values('Average', ascending=False)
avg_graph
# Out:
#                                                 Name   Average
# 3        Auberge Jeunesse LouLou's Backpacker Hostel  9.614286
# 0        HI-Quebec- Auberge Internationale de Québec  9.257143
# 1                                       QBEDS Hostel  9.042857
# 2                          Auberge de la Paix Quebec  8.628571
# 5                            Quebec Central Downtown  6.857143
# 4  La Belle Planete Backpacker Hostel Downtown Qu...  6.285714

# %%
top_ten = avg_graph.sort_values(by= 'Average', ascending=False)[:10]
figure = plt.figure()
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlim(0,10)
ax.set_xticks(range(0,11))
sns.barplot(y=top_ten.Name, x=top_ten.Average)
plt.xticks()
plt.xlabel('Average Rating')
plt.ylabel('Hostel Name')
plt.title('Top Hostels')
plt.show()
